# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Эдуард :)
#
# Спасибо за работу на проекте, за все исправления и комментарии
#
# Стоит завершить фильтрацию данных, учесть пропуски или нулевые маркеры при фильтрации, чтобы не потерять значительное кол-во записей, и вернуться к алгоритму заполнения пропусков, если он вызывает появление аномалий, в т.ч. видимых на графике, оптимальнее применить заглушку или оставить пропуски (важное примечание — на этом проекте)
#
# Стоит пересчитать скорость продаж, мы не исключили из расчета 3000 нулей
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Эдуард :) Спасибо за все доработки
#
# Критические ❌ комментарии остались
#
#
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограмму в п.4.1
# + поправить фильтрацию (оставить только питерские квартиры) и исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
# добавил подсказки
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Эдуард :) Спасибо за все исправления
#
# Критические ❌ комментарии остались
#
#
# + настроить фильтрацию редких значений в п. 2.4
# + добавить и подправить гистограммы в п.4.1
# + пересчитать скорость продаж
# + добавить вывод в п. 4.3
# + в ТОП-10 добавить график
# + поправить фильтрацию (оставить только питерские квартиры) и исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
# добавил подсказки и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Эдуард :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
# data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Временно добавил такой путь
#
#         df = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')

# %%
#Стоиит заменить название столбца cityCenters_nearest, parks_around3000, ponds_around3000
data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest', 'parks_around3000': 'parks_around_3000', 'ponds_around3000': 'ponds_around_3000'})

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Красота стиля важна для серъезных проектов, молодец

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %%
#Проверим название столбца
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
#Часы и минуты в таблице не нужны, для удобства заменимм формат даты.
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y%m%dT')
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
# Построим гисторгаму для числовых столбцов датасета
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не помешает добавить вывод после первого знакомства с данными

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# <h4>Определяем количество пропусков в столбцах датасета</h4>

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# За поворот текста отвечает параметр rot, можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках

# %% [markdown]
# В locality_name 49 и floors_total 86 слишком маленькое количество пропущенных знаачений. Такие значения лучше удалить, т.к. они не повлияют на анализ в дальнейшем.

# %%
#удалим значения
data = data.dropna(subset=['floors_total', 'locality_name'])

# %%
#Проверим
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9084
# floors_total                0
# living_area              1865
# floor                       0
# is_apartment            20805
# studio                      0
# open_plan                   0
# kitchen_area             2222
# balcony                 11475
# locality_name               0
# airports_nearest         5524
# city_centers_nearest     5501
# parks_around_3000        5500
# parks_nearest           15535
# ponds_around_3000        5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %%
# Определяем количество явных дубликатов
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет, идем дальше

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса
#
# __Оптимальнее поиск дубликатов выполнять после обработки неявных дубликатов__

# %%
#Выведем описательную статистику по датасету
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23565.000000  2.356500e+04  23565.000000  23565.000000    14481.000000
# mean       9.878421  6.540058e+06     60.322824      2.070656        2.771283
# std        5.681156  1.091093e+07     35.657060      1.078591        1.261983
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.510000
# 50%        9.000000  4.646000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.790000e+06     69.700000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23565.000000  21700.000000  23565.000000  21343.000000  12090.000000
# mean      10.675875     34.454822      5.878124     10.560994      1.157155
# ...

# %%
#Расчитаем процент пропусков
percent_prossing = round(data.isna().sum() * 100 / len(data))
print(percent_prossing.sort_values(ascending =False))
# Out:
# is_apartment            88.0
# parks_nearest           66.0
# ponds_nearest           62.0
# balcony                 49.0
# ceiling_height          39.0
# ponds_around_3000       23.0
# parks_around_3000       23.0
# city_centers_nearest    23.0
# airports_nearest        23.0
# days_exposition         13.0
# kitchen_area             9.0
# living_area              8.0
# locality_name            0.0
# total_images             0.0
# last_price               0.0
# studio                   0.0
# floor                    0.0
# floors_total             0.0
# rooms                    0.0
# first_day_exposition     0.0
# total_area               0.0
# open_plan                0.0
# dtype: float64

# %% [markdown]
# <ul>Описание данных
# <li>airports_nearest — расстояние до ближайшего аэропорта в метрах (м)</li>
# <li>balcony — число балконов</li>
# <li>ceiling_height — высота потолков (м)</li>
# <li>cityCenters_nearest — расстояние до центра города (м)</li>
# <li>days_exposition — сколько дней было размещено объявление (от публикации до снятия)</li>
# <li>first_day_exposition — дата публикации</li>
# <li>floor — этаж</li>
# <li>floors_total — всего этажей в доме</li>
# <li>is_apartment — апартаменты (булев тип)</li>
# <li>kitchen_area — площадь кухни в квадратных метрах (м²)</li>
# <li>last_price — цена на момент снятия с публикации</li>
# <li>living_area — жилая площадь в квадратных метрах (м²)</li>
# <li>locality_name — название населённого пункта</li>
# <li>open_plan — свободная планировка (булев тип)</li>
# <li>parks_around3000 — число парков в радиусе 3 км</li>
# <li>parks_nearest — расстояние до ближайшего парка (м)</li>
# <li>ponds_around3000 — число водоёмов в радиусе 3 км</li>
# <li>ponds_nearest — расстояние до ближайшего водоёма (м)</li>
# <li>rooms — число комнат</li>
# <li>studio — квартира-студия (булев тип)</li>
# <li>total_area — общая площадь квартиры в квадратных метрах (м²)</li>
# <li>total_images — число фотографий квартиры в объявлении</li>
# </ul>

# %% [markdown]
# <h4>Пропуски is_apartment</h4>

# %%
data['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %%
data['is_apartment'] = data['is_apartment'].fillna(False) #заменим на false

# %%
data['is_apartment'].describe()
# Out:
# count     23565
# unique        2
# top       False
# freq      23515
# Name: is_apartment, dtype: object

# %% [markdown]
# <h4>Пропуски balcony</h4>

# %%
data['balcony'].unique() #Если не указали количество балконов значит их скорее всего нет, 4-5 тоже сомнительно, но скорее всего это лоджия
# Out:
# array([nan,  2.,  0.,  1.,  5.,  4.,  3.])

# %%
data['balcony'] = data['balcony'].fillna(0) #Заменим на 0

# %%
data['balcony'] = data['balcony'].astype('int64') #Так же лучше заменить тип данных

# %%
data['balcony'].unique()
# Out:
# array([0, 2, 1, 5, 4, 3])

# %%
print('Количество пропусков balcony', data['balcony'].isna().sum()) #С балконами все впорядке
# Out:
# Количество пропусков balcony 0

# %% [markdown]
# <h4>Пропуски living_area</h4>

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9084
# floors_total                0
# living_area              1865
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2222
# balcony                     0
# locality_name               0
# airports_nearest         5524
# city_centers_nearest     5501
# parks_around_3000        5500
# parks_nearest           15535
# ponds_around_3000        5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %%
print('Количество пропусков living_area', data['living_area'].isna().sum())
# Out:
# Количество пропусков living_area 1865

# %%
data.sort_values(by='living_area')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21758             0   2330000.0       23.00           2018-01-01      0
# 13915            20   6350000.0       52.00           2018-02-06      2
# 23574            14  64990000.0      139.00           2015-11-24      3
# 3242              7   4440000.0       41.00           2017-07-02      1
# 17582            11   2680000.0       22.00           2018-08-11      0
# ...             ...         ...         ...                  ...    ...
# 23642            14   5950000.0       80.30           2018-07-03      3
# 23663            12   6400000.0       88.00           2018-01-12      4
# 23670             9   2450000.0       45.60           2018-02-08      1
# 23679             0   2500000.0       35.00           2017-12-08      1
# 23697            13  11475000.0       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
data['living_area'].unique()
# Out:
# array([51.  , 18.6 , 34.3 , ..., 31.65, 13.59, 42.55])

# %% [markdown]
# У квартиры студии, площадь кухни должна быть равна 0, т.к. она входит в жилую площадь. Заменим пропуски в столбце kitchen_area, в строках, где квартира является студией на значение 0.

# %%
data.loc[(data['kitchen_area'].isnull())&(data['studio'] == True), 'kitchen_area'] = 0

# %%
data.loc[data['living_area'].isnull(), 'living_area']  = round((data.groupby(['rooms'])['living_area'].transform('median') / data.groupby(['rooms'])['total_area'].transform('median') * data['total_area']),2)
data.loc[data['kitchen_area'].isnull(), 'kitchen_area']  = round((data.groupby(['rooms'])['kitchen_area'].transform('median') / data.groupby(['rooms'])['total_area'].transform('median') * data['total_area']),2)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %%
print('Количество пропусков living_area', data['living_area'].isna().sum())
# Out:
# Количество пропусков living_area 0

# %%
print('Количество пропусков kitchen_area', data['kitchen_area'].isna().sum())
# Out:
# Количество пропусков kitchen_area 0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверку ⬆⬆⬆ проводят по  другому ⬇⬇⬇
#
#         После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
#         если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %%
# check
data[data['total_area']*0.9 <= (data['living_area'] + data['kitchen_area'])]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 41               16   7900000.0        74.0           2016-05-04      3
# 171               6   3800000.0        49.0           2019-02-22      2
# 184               7   2600000.0        30.2           2018-02-14      1
# 220               8   3890000.0        37.0           2018-07-09      1
# 319              19   4850000.0        59.7           2015-03-19      3
# ...             ...         ...         ...                  ...    ...
# 23328            12   4299000.0        54.0           2016-11-25      2
# 23420             1   3345000.0        29.9           2018-08-09      1
# 23521            13   8500000.0        65.0           2018-11-01      2
# 23579             7   2350000.0        24.8           2018-06-07      1
# 23680            14   5000000.0        59.0           2019-04-04      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'black', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Аномалии проявились на графике (прямая неестественная для облака линия) — стоит принять решение или изменить алгоритм заполнения пропусков, или оставить пропуски, или заполнить маркерами
#
# при изменении способа обработки колонок, стоит перепроверить код фильтрации
#
# __Самое важное — приобрести навык__ — любая замена пропусков очень трудоемка по ресурсам, т.к. приходится искать оптимальный вариант и если можно работать, имея пропуски в данных — лучше отказаться от заполнения
#
# но есть другие случаи, когда пропуски заполнять обязательно нужно, на проекте по стат. анализу — внимательно посмотри на пропуски в данных в объединенной таблице (кроме даты оттока клиентов)
#
# в итоге каждый раз мы вынуждены будем принимать решение — заполнять пропуски и как заполнять, или оставлять

# %% [markdown]
# <h4>Пропуски ceiling_height</h4>

# %%
data['ceiling_height'].describe()
# Out:
# count    14481.000000
# mean         2.771283
# std          1.261983
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data.boxplot(column='ceiling_height')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Высота потолка 100, возможно это какая то башня. Все же лучше сделать медиану

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())
print('Количество пропусков ceiling_height', data['ceiling_height'].isna().sum())
# Out:
# Количество пропусков ceiling_height 0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении средним или медианой необходимо четко отслеживать изменение других статистик: стандартное отклонение, дисперсию и другие параметры выборки
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %%
data['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.724530
# std          0.991026
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# city_centers_nearest     5501
# parks_around_3000        5500
# parks_nearest           15535
# ponds_around_3000        5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# <h4>Пропуски kitchen_area</h4>

# %%
data['kitchen_area'].describe()
# Out:
# count    23565.000000
# mean        10.398943
# std          5.861190
# min          0.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.780000
# max        121.500000
# Name: kitchen_area, dtype: float64

# %%
data.boxplot(column='kitchen_area')
# Out:
# <AxesSubplot:>

# %%
data.sort_values(by='kitchen_area')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 7818             11    3300000.0       27.30           2018-04-06      0
# 19477            11    2300000.0       20.00           2017-11-10      0
# 12996             8    1900000.0       18.00           2019-01-25      0
# 10606            14    2950000.0       25.27           2017-11-17      0
# 15712            12    3000000.0       29.00           2018-02-27      0
# ...             ...          ...         ...                  ...    ...
# 5358             20   65000000.0      590.00           2019-02-14     15
# 2489              9   12500000.0      255.00           2017-04-21      3
# 20215             2   85000000.0      249.70           2018-02-01      3
# 19540             8  420000000.0      900.00           2017-12-06     12
# 9826              1   43185328.0      494.10           2017-05-12      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
# ...

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(data.groupby('rooms')['kitchen_area'].transform('median'))
print('Количество пропусков:', data['kitchen_area'].isna().sum())
# Out:
# Количество пропусков: 0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ко времени исполнения этой строки кода
#
#         data['kitchen_area'] = data['kitchen_area'].fillna(data.groupby('rooms')['kitchen_area'].transform('median'))
#
# у нас не осталось пропусков в колонке площади кухни

# %%
data.pivot_table(index='rooms', values='kitchen_area', aggfunc=('median', 'count'))
# Out:
#        count   median
# rooms
# 0        194    0.000
# 1       8004    9.000
# 2       7897    8.700
# 3       5779    9.500
# 4       1172   11.000
# 5        325   15.000
# 6        104   19.775
# 7         59   20.000
# 8         12   25.495
# 9          8   13.750
# 10         3   19.800
# 11         2   12.600
# 12         1  112.000
# 14         2   21.250
# 15         1  100.000
# 16         1   13.000
# 19         1   27.600

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# city_centers_nearest     5501
# parks_around_3000        5500
# parks_nearest           15535
# ponds_around_3000        5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# <h4>Пропуски days_exposition</h4>

# %%
data['days_exposition'].unique()
# Out:
# array([  nan,   81.,  558., ..., 1360., 1007.,  971.])

# %%
data['days_exposition'] = data['days_exposition'].fillna(0).astype('int')

# %%
data['days_exposition'].unique()
# Out:
# array([   0,   81,  558, ..., 1360, 1007,  971])

# %% [markdown]
# <h4>Устранение неявных дубликатов в населенных пунктах</h4>

# %%
sorted(data['locality_name'].unique())
# Out:
# ['Бокситогорск',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Высоцк',
#  'Гатчина',
#  'Зеленогорск',
#  'Ивангород',
#  'Каменногорск',
#  'Кингисепп',
#  'Кириши',
#  'Кировск',
#  'Колпино',
#  'Коммунар',
#  'Красное Село',
#  'Кронштадт',
#  'Кудрово',
#  'Лодейное Поле',
#  'Ломоносов',
#  'Луга',
#  'Любань',
#  'Мурино',
#  'Никольское',
#  'Новая Ладога',
#  'Отрадное',
#  'Павловск',
#  'Петергоф',
#  'Пикалёво',
#  'Подпорожье',
#  'Приморск',
#  'Приозерск',
#  'Пушкин',
#  'Санкт-Петербург',
#  'Светогорск',
#  'Сертолово',
#  'Сестрорецк',
#  'Сланцы',
#  'Сосновый Бор',
#  'Сясьстрой',
#  'Тихвин',
#  'Тосно',
#  'Шлиссельбург',
#  'городской поселок Большая Ижора',
#  'городской поселок Янино-1',
#  'городской посёлок Будогощь',
#  'городской посёлок Виллози',
#  'городской посёлок Лесогорский',
#  'городской посёлок Мга',
#  'городской посёлок Назия',
#  'городской посёлок Новоселье',
#  'городской посёлок Павлово',
#  'городской посёлок Рощино',
# ...

# %%
len(data['locality_name'].unique()) #Кол-во уникальных значений
# Out:
# 364

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
data['locality_name'] = data['locality_name'].str.replace('городской поселок ','')
data['locality_name'] = data['locality_name'].str.replace('коттеджный поселок ','')
data['locality_name'] = data['locality_name'].str.replace('поселок при железнодорожной станции ','')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа ','')
data['locality_name'] = data['locality_name'].str.replace('поселок станции ','')
data['locality_name'] = data['locality_name'].str.replace('садовое товарищество ','')
data['locality_name'] = data['locality_name'].str.replace('садоводческое некоммерческое товарищество ','')
data['locality_name'] = data['locality_name'].str.replace('село ','')
data['locality_name'] = data['locality_name'].str.replace('поселок ','')
data['locality_name'] = data['locality_name'].str.replace('деревня ','')
data['locality_name'] = data['locality_name'].str.replace('имени ','')

# %%
len(data['locality_name'].unique())
# Out:
# 305

# %%
sorted(data['locality_name'].unique())
# Out:
# ['Агалатово',
#  'Александровская',
#  'Алексеевка',
#  'Аннино',
#  'Аро',
#  'Барышево',
#  'Батово',
#  'Бегуницы',
#  'Белогорка',
#  'Белоостров',
#  'Бокситогорск',
#  'Большая Вруда',
#  'Большая Ижора',
#  'Большая Пустомержа',
#  'Большие Колпаны',
#  'Большое Рейзино',
#  'Большой Сабск',
#  'Бор',
#  'Борисова Грива',
#  'Бугры',
#  'Будогощь',
#  'Ваганово',
#  'Важины',
#  'Вартемяги',
#  'Вахнова Кара',
#  'Вещево',
#  'Виллози',
#  'Вознесенье',
#  'Возрождение',
#  'Войсковицы',
#  'Войскорово',
#  'Володарское',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Вырица',
#  'Выскатка',
#  'Высокоключевой',
#  'Высоцк',
#  'Гаврилово',
#  'Гарболово',
#  'Гатчина',
#  'Гладкое',
#  'Глажево',
#  'Глебычево',
#  'Глинка',
#  'Гончарово',
#  'Горбунки',
#  'Гостилицы',
#  'Громово',
#  'Дзержинского',
#  'Дружная Горка',
#  'Дружноселье',
#  'Дубровка',
#  'Елизаветино',
#  'Ефимовский',
#  'Жилгородок',
#  'Жилпоселок',
#  'Житково',
#  'Заводской',
# ...

# %%
# check
data.locality_name.nunique()
# Out:
# 305

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# #### check gap

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
# ...

# %%
data['floors_total'] =  data['floors_total'].astype('int')
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.65            11        18.60      1         False  ...
# 2            2.65             5        34.30      4         False  ...
# 3            2.65            14        98.28      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0         25.00        0  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <h4>Поиск и обработка аномалий</h4>

# %%
data_parameters = data.loc[:,['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total']]

for column in data_parameters:
    plt.figure(figsize=(8,8))
    data_parameters[column].plot(kind='hist', bins=100, grid=True).set_title(column)

# %%
data['total_area'].plot(kind='box',figsize=(3,5)) #построим диаграмму размаха для общей площади  
plt.ylim(0, 150) #диапазон 150 кв.м
plt.show()
data['total_area'].plot(kind='box',figsize=(3,5))
plt.ylim(0, 15) #диапазон от 0 до 15 кв. м
plt.show()
data['total_area'].plot(kind='box',figsize=(3,5))
plt.ylim(114, 115) #от 114 до 115 кв. м
plt.show()

# %% [markdown]
# Выбросы по площади квартир находятся до 12 кв.м и от 114 кв.м

# %%
data['last_price'].plot(kind='box',figsize=(3,5)) #построим диаграмму размаха для количества комнат
plt.show()
data['last_price'].plot(kind='box',figsize=(3,5))
plt.ylim(0, 20000) 
plt.show()
data['last_price'].plot(kind='box',figsize=(3,5))
plt.ylim(11800000, 11900000) 
plt.show()

# %% [markdown]
# Нормальная стоимость квартиры находится в диапазоне от 12 500 руб. до 11 840 000 руб.

# %%
data['ceiling_height'].plot(kind='box',figsize=(3,5)) #построим диаграмму размаха для количества комнат
plt.show()
data['ceiling_height'].plot(kind='box',figsize=(3,5))
plt.ylim(2.3, 2.5) 
plt.show()
data['ceiling_height'].plot(kind='box',figsize=(3,5))
plt.ylim(2.7, 2.9) 
plt.show()

data['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.724530
# std          0.991026
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Большинство квартир имееют высоту потолков от 2.45 м до 2.85 м

# %%
data['rooms'].plot(kind='box',figsize=(3,5)) #построим диаграмму размаха для количества комнат
plt.ylim(0, 8) 
plt.show()

# %% [markdown]
# Большинство квартир имеет не более 6 комнат.

# %%
data['living_area'].plot(kind='box',figsize=(3,5)) #построим диаграмму размаха для количества комнат
plt.show()
data['living_area'].plot(kind='box',figsize=(3,5))
plt.ylim(0, 70) 
plt.show()
data['living_area'].plot(kind='box',figsize=(3,5))
plt.ylim(60, 100) 
plt.show()

data['living_area'].describe()
# Out:
# count    23565.000000
# mean        34.637029
# std         22.770880
# min          2.000000
# 25%         18.700000
# 50%         30.000000
# 75%         42.300000
# max        427.550000
# Name: living_area, dtype: float64

# %% [markdown]
# Основная часть квартир с жилой площадью до 66 кв.

# %%
data['kitchen_area'].plot(kind='box',figsize=(3,5)) #построим диаграмму размаха для количества комнат
plt.show()
data['kitchen_area'].plot(kind='box',figsize=(3,5))
plt.ylim(0, 2.5) 
plt.show()
data['kitchen_area'].plot(kind='box',figsize=(3,5))
plt.ylim(1, 20) 
plt.show()

data['kitchen_area'].describe()
# Out:
# count    23565.000000
# mean        10.398943
# std          5.861190
# min          0.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.780000
# max        121.500000
# Name: kitchen_area, dtype: float64

# %%
data['days_exposition'].plot(kind='box',figsize=(3,5)) #построим диаграмму размаха для количества комнат
plt.show()
data['days_exposition'].plot(kind='box',figsize=(3,5))
plt.ylim(0, 500) 
plt.show()
data['days_exposition'].plot(kind='box',figsize=(3,5))
plt.ylim(1, 20) 
plt.show()

data['days_exposition'].describe()
# Out:
# count    23565.000000
# mean       156.420115
# std        213.517293
# min          0.000000
# 25%         22.000000
# 50%         73.000000
# 75%        198.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
#data = data.query('(12 <= total_area <=220) and rooms <7 and (ceiling_height > 2) and (12500 <= last_price <= 100000000) and (1 <= days_exposition <= 600) and (12 <= living_area <= 90) and (0 <= kitchen_area <= 25)')

# %% [markdown]
# #### check nan

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %%
data.boxplot(column='ceiling_height', figsize=(8, 6))
plt.title('Высота потолоков')
plt.ylim(1, 7)
plt.ylabel('высота, м')
plt.show()

# %%
q1 = data['kitchen_area'].quantile(.25) # первый квартиль Q1
q3 = data['kitchen_area'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR

# Построим гистограмму площади
data['kitchen_area'].hist(bins=30, range=((q1 - 1.5 * iqr), (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Площадь кухни объектов недвижимости')
plt.xlabel('м²')
plt.ylabel('объекты недвижимости')
plt.show()

# %%
print('Среднее значение', data['kitchen_area'].mean())
print('Медианное значение', data['kitchen_area'].median())
print('Минимальное значение', data['kitchen_area'].min())
print('Максимальное значение', data['kitchen_area'].max())
print(data['kitchen_area'].hist(bins=50, range=(4, 25)))
# Out:
# Среднее значение 10.398943348185869
# Медианное значение 9.0
# Минимальное значение 0.0
# Максимальное значение 121.5
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
data.boxplot(column='kitchen_area', figsize=(8, 6))
plt.title('Площадь кухни')
plt.ylim(1, 20)
plt.ylabel('Площадь')
plt.show()

# %%
print('Среднее значение', data['days_exposition'].mean())
print('Медианное значение', data['days_exposition'].median())
print('Минимальное значение', data['days_exposition'].min())
print('Максимальное значение', data['days_exposition'].max())
print(data['days_exposition'].hist(bins=50, range=(4, 25)))
# Out:
# Среднее значение 156.42011457670273
# Медианное значение 73.0
# Минимальное значение 0
# Максимальное значение 1580
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
data.boxplot(column='days_exposition', figsize=(8, 6))
plt.title('Дней размещения')
plt.ylim(1, 20)
plt.ylabel('Дней')
plt.show()

# %%
print(data.shape[0])
data = data[(data['total_area'] >= 12 ) & (data['total_area'] <= 250)]
data = data[data['last_price'] <= 100000000]
data = data[(data['ceiling_height'] >= 2.5) & (data['ceiling_height'] <= 5)]
print(data.shape[0])
data = data[data['floors_total'] <= 30]
data = data[data['rooms'] < 7]

print(data.shape[0])
#data = data[(data['days_exposition'] >= 1 ) & (data['days_exposition'] <= 1200)]
data = data[data['days_exposition'] <= 1200]
print(data.shape[0])
data = data[(data['living_area'] >= 12 ) & (data['living_area'] <= 90)]
data = data[(data['kitchen_area'] >= 4 ) & (data['kitchen_area'] <= 25)]

print(data.shape[0])
# Out:
# 23565
# 23335
# 23254
# 23166
# 22013

# %%
# check
data.shape[0]
# Out:
# 22013

# %% [markdown]
# Если я фильрую days_exposition нулевые значения, то я теряю большой процент записей.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         data = data[(data['days_exposition'] >= 1 ) & (data['days_exposition'] <= 600)]
#         print(data.shape[0])
#         data = data[(data['living_area'] >= 12 ) & (data['living_area'] <= 90)]
#         data = data[(data['kitchen_area'] >= 1 ) & (data['kitchen_area'] <= 25)]
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Минус 5 000 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %%
(data['ceiling_height'] <= 10).hist()
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot:>

# %%
(data['kitchen_area'] <= 25).hist()
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot:>

# %%
data.boxplot(column='ceiling_height', figsize=(8, 6))
plt.title('Высота потолоков')
plt.ylim(1, 6)
plt.ylabel('высота, м')
plt.show()

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит нарисовать гистограмму и не гадать
#
#         & (data['ceiling_height'] <= 10)]

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выборка data['days_exposition'] имеет длинный правый хвост, не стоит обрезать подобный хвост на таких значениях, оптимально ориентироваться на значения 0,99 квантиля, это где-то 1200 дней ...
#
#         data = data[(data['days_exposition'] >= 1 ) & (data['days_exposition'] <= 600)]

# %% [markdown]
# <div class="alert alert-dange r">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     (... total_area <=114.4) and (... ceiling_height <=2.85) and ( ... last_price <=11840000)
#
# Слишком жесткие условия для фильтрации выборки, особенно для Питера и его исторической части, стоит посмотреть на гистограмму параметра, чтобы определить, где начинаются редкие значения
#
# Если при фильтрации одной колонки, на этом проекте, теряем больше одного процента данных от изначального объема, стоит еще раз пересмотреть условия фильтрации

# %%
(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_8ac15_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ac15_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_8ac15_row0_col0" class="data row0 col0" >22,013.00</td>
#                         <td id="T_8ac15_row0_col1" class="data row0 col1" >22,013.00</td>
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит сменить тип данных в
#
#          6   floors_total          23565 non-null  float64

# %% [markdown]
# Заменил

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_75afc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75afc_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_75afc_row0_col0" class="data row0 col0" >22,013.00</td>
#                         <td id="T_75afc_row0_col1" class="data row0 col1" >22,013.00</td>
# ...

# %%
# check
data.hist(column = 'kitchen_area', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'kitchen_area', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %%
# check
data.hist(column = 'rooms', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'rooms', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %%
# check
data.hist(column = 'rooms', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'rooms', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались редкости в  скорости продаж: один или два дня, нулевые маркеры стоит сохранить
#
# оставлю пример сложной фильтрации в бонусной части

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#            'days_exposition',    'kitchen_area', 'ceiling_height'
#
# для определения хвостов, редкостей и аномалий смотрим на минимальные и максимальные значения, строим несколько гистограмм по каждому параметру
#
# например в таблице мы видим аномалию квартиру с кухней равной двум кв. метрам..., а на гистограмме аномальную скорость продаж в один или два дня
#
# стоит учесть наличие пропусков или нулевых маркеров при фильтрации данных

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#            'days_exposition',  'living_area',  'kitchen_area'
#
# для определения хвостов, редкостей и аномалий смотрим на минимальные и максимальные значения, строим несколько гистограмм по каждому параметру
#
# например в таблице мы видим аномалию квартиру с жилой площадью равной двум кв. метрам..., а на гистограмме аномальную скорость продаж в один или два дня
#
# стоит учесть наличие пропусков или нулевых маркеров при фильтрации данных

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %%
# (data['kitchen_area'] <= 10).hist()

# %%
# check
data[data['kitchen_area'] <= 10].hist();

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Подобная гистограмма строится иначе
#
#         (data['kitchen_area'] <= 10).hist()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 0     197
# 6     105
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %%
df_check.kitchen_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_a865e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a865e_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_a865e_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_a865e_row0_col1" class="data row0 col1" >22.70</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# <h4>Цена квадратного метра </h4>

# %%
data['price_metr'] = (data['last_price'] / data['total_area']).astype('int')
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16        51.00      8         False  ...
# ...

# %% [markdown]
# <h4>День недели публикации объявления</h4>

# %%
data['day_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16        51.00      8         False  ...
# ...

# %% [markdown]
# <h4>Тип этажа квартиры </h4>

# %%
def floor_category(row):
    if row['floor'] == 1:
        return 'Первый'
    if row['floor'] == row['floors_total']: 
        return 'Последний'
    return 'Другой'

data['floor_category'] = data.apply(floor_category, axis = 1)
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16        51.00      8         False  ...
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %% [markdown]
# <h4>Расстояние до центра города в километрах (переведите из м в км и округлите до целых значений</h4>

# %%
data.loc[:,'distance_to_the_center'] = (data.loc[:, 'city_centers_nearest']  / 1000) 
data['distance_to_the_center'] = round(data['distance_to_the_center'])
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16        51.00      8         False  ...
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит выполнить пункт проекта
#
# •	расстояние до центра города в километрах (переведите из м в км и __округлите до целых значений__).

# %% [markdown]
# Сделал

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# <h4>Общая площадь</h4>

# %%
data['total_area'].describe()
# Out:
# count    22013.000000
# mean        56.119653
# std         22.095277
# min         17.600000
# 25%         40.000000
# 50%         51.000000
# 75%         67.000000
# max        236.000000
# Name: total_area, dtype: float64

# %%
data.boxplot(column='total_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Компактность графика

# %%
# check
# для примера горизонтальный вид диаграммы размаха

fig, ax = plt.subplots(figsize = (17,2))
ax = data[['total_area']].boxplot(vert = False, ax =ax)
ax.set_title('Диаграмма размаха значений площади')
ax.set_xlim(0, 400);

# %%
data['total_area'].hist(bins=50, range=(0, 120))
plt.xlabel("общая площадь")
plt.ylabel("количество")
plt.show()

# %%
print('Среднее:', data['total_area'].mean())
print('Медиана:', data['total_area'].median())
# Out:
# Среднее: 56.11965293235815
# Медиана: 51.0

# %% [markdown]
# Наибольшее количество квартир имеет площадь в районе 28-70 метров.

# %% [markdown]
# <h4>Жилая площадь</h4>

# %%
data['living_area'].describe()
# Out:
# count    22013.000000
# mean        32.214666
# std         14.825466
# min         12.000000
# 25%         18.610000
# 50%         30.000000
# 75%         41.200000
# max         90.000000
# Name: living_area, dtype: float64

# %%
data.boxplot(column='living_area')
# Out:
# <AxesSubplot:>

# %%
data['living_area'].hist(bins=50, range=(0, 80))
plt.xlabel("жилая площадь")
plt.ylabel("количество")
plt.show()

# %%
print('Среднее:', data['living_area'].mean())
print('Медиана:', data['living_area'].median())
# Out:
# Среднее: 32.214665947849
# Медиана: 30.0

# %% [markdown]
# Самые популярные это квартиры до 20кв метров,  это квртиры студии, дальше идут однокомнатные и двухкомнатные квартиры

# %% [markdown]
# <h4>Площадь кухни</h4>

# %%
data['kitchen_area'].describe()
# Out:
# count    22013.000000
# mean         9.707223
# std          3.523251
# min          4.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.100000
# max         25.000000
# Name: kitchen_area, dtype: float64

# %%
data.boxplot(column='kitchen_area')
# Out:
# <AxesSubplot:>

# %%
data['kitchen_area'].hist(bins = 50, range = (0, 20))
plt.xlabel("площадь кухни")
plt.ylabel("количество")
plt.show()

# %%
print('Среднее:', data['kitchen_area'].mean())
print('Медиана:', data['kitchen_area'].median())
# Out:
# Среднее: 9.707223458865217
# Медиана: 9.0

# %% [markdown]
# Основная масса квартир имеет площаль кухни менее 15 метров, много в районе 5-10 метров.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно добавить изменить размер у графиков (увеличить ширину)
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# <h4>Иследование количества комнат</h4>

# %%
data['rooms'].describe()
# Out:
# count    22013.000000
# mean         2.006133
# std          0.920622
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %%
data['rooms'].hist()
plt.xlabel("количество комнат")
plt.ylabel("количество")
plt.show()

# %%
data['rooms'].hist(bins = 5, range = (0, 5))
plt.xlabel("количество комнат")
plt.ylabel("количество")
plt.show()

# %% [markdown]
# Наиболее часто продаются 1 и 2х комнатные квартиры.

# %% [markdown]
# <h4>Иследование высоты потолков</h4>

# %%
data['ceiling_height'].describe()
# Out:
# count    22013.000000
# mean         2.684188
# std          0.195552
# min          2.500000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          5.000000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].hist()
plt.xlabel("высота")
plt.ylabel("количество")
plt.show()

# %%
data['ceiling_height'].hist(bins = 5, range = (2, 4))
plt.xlabel("высота")
plt.ylabel("количество")
plt.show()

# %%
print('Среднее:', data['ceiling_height'].mean())
print('Медиана:', data['ceiling_height'].median())
# Out:
# Среднее: 2.684188434107118
# Медиана: 2.65

# %% [markdown]
# Средня выстота потолков 2.7 метра

# %% [markdown]
# <h4>Общее количество этажей в доме</h4>

# %%
data['floor'].describe()
# Out:
# count    22013.000000
# mean         5.856221
# std          4.842363
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         27.000000
# Name: floor, dtype: float64

# %%
data['floor'].hist(bins =20, range = (1, 10))
plt.xlabel("колическтво этажей")
plt.ylabel("количество")
plt.show()

# %%
data.plot(y='floor',
          kind='hist',
          bins=40,
          figsize=(8, 5),
          range=(0, 30),
          grid=True          
         )
plt.title('Этаж квартиры')
# Out:
# Text(0.5, 1.0, 'Этаж квартиры')

# %%
data['floors_total'].describe()
# Out:
# count    22013.000000
# mean        10.676328
# std          6.520076
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         29.000000
# Name: floors_total, dtype: float64

# %%
plt.hist(data['floors_total'], bins=50, range=(1,30))
plt.title('Общее количество этажей в доме')
plt.xlabel('Этажи')
plt.ylabel('Количество квартир')
plt.grid(which='major')
plt.show()
print('Наибольшие значения по общему количеству этажей в доме')
data['floors_total'].sort_values(ascending=False).head(10)
# Out:
# Наибольшие значения по общему количеству этажей в доме
# 3797     29
# 19139    28
# 7711     28
# 14719    28
# 6397     28
# 18183    28
# 23544    28
# 14018    28
# 12950    28
# 324      28
# Name: floors_total, dtype: int64

# %% [markdown]
# В основном квртиры в продаже в пятиэтажных домах, далее идут девятиэтажные.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас  трудно определить типовую высотность зданий

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 4-ке, или на 5-ке, или на 6-ке ...

# %%
# check
data.plot(y='floor',
          kind='hist',
          bins=60,
          figsize=(8, 5),
          range=(0, 30),
          grid=True          
         )
plt.title('Этаж квартиры')
# Out:
# Text(0.5, 1.0, 'Этаж квартиры')

# %% [markdown]
# Категория этажа

# %%
data['floor_category'].hist()
data['floor_category'].value_counts()
# Out:
# Другой       16174
# Последний     3060
# Первый        2779
# Name: floor_category, dtype: int64

# %%
print('Среднее:', data['floor'].mean())
print('Медиана:', data['floor'].median())
# Out:
# Среднее: 5.856221323763231
# Медиана: 4.0

# %% [markdown]
# Среднее 5 этажей, что говорит о старом фонде и вторичности жилья.

# %% [markdown]
# <h4>Расстояние до центра города в метрах</h4>

# %%
data['city_centers_nearest'].describe()
# Out:
# count    16732.000000
# mean     14535.296318
# std       8566.783291
# min        208.000000
# 25%       9888.000000
# 50%      13278.000000
# 75%      16446.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %%
data['city_centers_nearest'].hist(bins = 20, range = (0, 70000))
plt.xlabel("расстояние")
plt.ylabel("количество")
plt.show()

# %%
print('Среднее:', data['city_centers_nearest'].mean())
print('Медиана:', data['city_centers_nearest'].median())
# Out:
# Среднее: 14535.296318431747
# Медиана: 13278.0

# %% [markdown]
# Среднее расстояние до центра города 14000 метров

# %% [markdown]
# <h4>Расстояние до ближайшего аэропорта</h4>

# %%
data['airports_nearest'].describe()
# Out:
# count    16713.000000
# mean     28889.737091
# std      12792.926167
# min          0.000000
# 25%      18344.000000
# 50%      27011.000000
# 75%      37434.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
data['airports_nearest'].hist(bins = 20, range = (0, 100000))
plt.xlabel("расстояние")
plt.ylabel("количество")
plt.show()

# %%
print('Среднее:', data['airports_nearest'].mean())
print('Медиана:', data['airports_nearest'].median())
# Out:
# Среднее: 28889.737090887334
# Медиана: 27011.0

# %% [markdown]
# Среднее до ближайшего аэропорта 28000 метров

# %% [markdown]
# <h4>Расстояние до парка</h4>

# %%
data['parks_nearest'].describe()
# Out:
# count    7273.000000
# mean      493.228654
# std       340.311300
# min         1.000000
# 25%       289.000000
# 50%       457.000000
# 75%       616.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
data['parks_nearest'].hist(bins = 20, range = (0, 3200))
plt.xlabel("расстояние")
plt.ylabel("количество")
plt.show()

# %%
print('Среднее:', data['parks_nearest'].mean())
print('Медиана:', data['parks_nearest'].median())
# Out:
# Среднее: 493.2286539254778
# Медиана: 457.0

# %% [markdown]
# Основная масса парков расположена в пешей доступности до 500 метров

# %% [markdown]
# <h4>День и месяц публикации объявления</h4>

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 5            10   2890000.0        30.4           2018-09-10      1
# 7             5   7915000.0        71.6           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 5            2.65            12         14.4      5         False  ...
# 7            2.65            24         41.2     22         False  ...
#
#    parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# ...

# %%
data['day_exposition'].describe()
# Out:
# count    22013.000000
# mean         2.572162
# std          1.790659
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max          6.000000
# Name: day_exposition, dtype: float64

# %%
pivot_table_date_category = data.pivot_table(index = 'day_exposition', values = 'month_exposition', aggfunc = 'count').reset_index() # сводная таблица была необязательна, но показалось проще посчитать таким методом
sns.barplot(x='day_exposition', y='month_exposition', data = pivot_table_date_category).set_ylabel('Frequency') # барплот по дням недели выглядит интереснее
plt.title("Частота публикации объявлений по дням недели")
# Out:
# Text(0.5, 1.0, 'Частота публикации объявлений по дням недели')

# %%
data['month_exposition'].describe()

data.plot(y = 'month_exposition', kind = 'hist', bins = 24, grid=True, figsize = (8,3), range = (1, 12))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Наиболее часто публикуют объявления в будние дни. Ноябрь ,февраль, апрель и март самые популярные месяцы продажи

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Осталось добавить одну гистограмму
#
# Шаг 4. Проведите исследовательский анализ данных:
# 1.	Изучите следующие параметры объектов:
#     +	общая площадь;
#     +	жилая площадь;
#     +	площадь кухни;
#     +	цена объекта;
#     +	количество комнат;
#     +	высота потолков;
#     +	этаж квартиры;
#     +	тип этажа квартиры («первый», «последний», «другой»);
#     +	__общее количество этажей в доме;__
#     +	расстояние до центра города в метрах;
#     +	расстояние до ближайшего аэропорта;
#     +	расстояние до ближайшего парка;
#     +	день и месяц публикации объявления.
#
#
# __Постройте отдельные гистограммы для каждого из этих параметров.__ Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %% [markdown]
# <h4>Как быстро продавались квартиры</h4>

# %%
data['days_exposition'].describe()
# Out:
# count    22013.000000
# mean       150.559851
# std        198.842534
# min          0.000000
# 25%         23.000000
# 50%         72.000000
# 75%        194.000000
# max       1200.000000
# Name: days_exposition, dtype: float64

# %%
data[data['days_exposition']!=0]['days_exposition'].hist(bins = 20, range = (0, 1000))
plt.xlabel("дней")
plt.ylabel("количество")
plt.show()

# %%
data[data['days_exposition']!=0]['days_exposition'].hist(bins = 20, range = (0, 200))
plt.xlabel("дней")
plt.ylabel("количество")
plt.show()

# %%
data[data['days_exposition']!=0]['days_exposition'].describe()
# Out:
# count    19149.000000
# mean       173.078176
# std        203.849307
# min          1.000000
# 25%         44.000000
# 50%         93.000000
# 75%        223.000000
# max       1200.000000
# Name: days_exposition, dtype: float64

# %%
data.plot(y = 'days_exposition', kind = 'hist', bins = 30, grid = True, range = (1,1600))
data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (1,200))

#среднее значение, медиана и межквартильный размах
data[data['days_exposition']!=0]['days_exposition'].describe()
data[data['days_exposition']!=0]['days_exposition'].value_counts()
# Out:
# 45      844
# 60      528
# 7       218
# 30      192
# 4       168
#        ...
# 822       1
# 806       1
# 790       1
# 774       1
# 1111      1
# Name: days_exposition, Length: 1042, dtype: int64

# %%
data.plot(y = 'days_exposition', kind = 'hist', bins = 20, grid=True, figsize = (8,3), range = (0, 200))
plt.grid(which='major')

# %%
print('Среднее:', data['days_exposition'].mean())
print('Медиана:', data['days_exposition'].median())
# Out:
# Среднее: 150.55985099713806
# Медиана: 72.0

# %% [markdown]
# Время продажи (медиана): 72 дней.
#
# Время продажи (среднее): 150 дней.
#
# В основном квартиры продаются в срок до 100 дней.
#
# Быстрой продажей можно считать срок до 45 дней. Долгой продажей - 200 дней.

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,50));

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В расчете скорости продаж не исключены нулевые заглушки, более 3000 записей с нулевой скоростью продаж искажают среднее и медианное значения
#
# Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В расчете скорости продаж не исключены нулевые заглушки, более 3000 записей с нулевой скоростью продаж искажают среднее и медианное значения
#
# Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Мы заполнили пропуски в колонке нулями, которые снижают медианную и среднюю скорости продаж
#
# __стоит их временно исключить из расчета при помощи фильтрации__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для определения быстрых и долгих продаж оптимальнее ориентироваться на 25-тый и 75-тый квантили

# %% [markdown]
# <h4>Влияние общей площади</h4>

# %%
data['total_area'].corr(data['last_price'])
# Out:
# 0.7036271395808095

# %%
sns.scatterplot(x=data['total_area'], y=data['last_price'] / 1000000, alpha=.3) # перевели цены в миллионы для наилучшего отображения

plt.title('Влияние общей площади', size=10)
plt.xlabel('Общая площадь', size=10)
plt.ylabel('Стоимость', size=10)
plt.ylim(0, 200)
plt.xlim(0, 800)
plt.show()

# %% [markdown]
# Существует незначительная связь между ценой и общей площадью

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не стоит за счет комментариев увеличивать ширину строки

# %% [markdown]
# <h4>Влияние жилой площади</h4>

# %%
data['last_price'].corr(data['living_area'])
# Out:
# 0.6042882845096021

# %%
sns.scatterplot(x=data['living_area'], y=data['last_price'] / 1000000, alpha=.3) # перевели цены в миллионы для наилучшего отображения

plt.title('Влияние жилой площади', size=10)
plt.xlabel('Жилая площадь', size=10)
plt.ylabel('Стоимость квартиры', size=10)
plt.ylim(0, 200)
plt.xlim(0, 500)
plt.show()

# %% [markdown]
# Коэффициент корреляции не равен единице - очевидно, что цена будет зависеть и от других факторов.

# %% [markdown]
# <h4>Влияние площади кухни</h4>

# %%
data['last_price'].corr(data['kitchen_area'])
# Out:
# 0.5134162740518287

# %%
sns.scatterplot(x=data['kitchen_area'], y=data['last_price'] / 1000000, alpha=.3) # перевели цены в миллионы для наилучшего отображения

plt.title('Влияние площади кухни', size=10)
plt.xlabel('Жилая площадь', size=10)
plt.ylabel('Стоимость квартиры', size=10)
plt.ylim(0, 200)
plt.xlim(0, 100)
plt.show()

# %% [markdown]
# Низкое влияние площади кухня на стоимость квартиры

# %% [markdown]
# <h4>Влияние количество комнат</h4>

# %%
rooms_pivot = data.pivot_table(index='rooms', values='last_price', aggfunc=['count', 'mean', 'median'])
rooms_pivot.columns = ['count', 'mean', 'median']
rooms_pivot.query('rooms < 10').plot(y='median')
# Out:
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# Больше комнат,больше стоимость квартиры.

# %% [markdown]
# <h4>Тип этажа, на котором расположена квартира</h4>

# %%
floor_category_pivot = data.pivot_table(index='floor_category', values='last_price', aggfunc=['count', 'mean', 'median'])
floor_category_pivot.columns = ['count', 'mean', 'median']
floor_category_pivot.plot(y='median')
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# Первый и последний этаж самые недорогие.

# %% [markdown]
# <h4>Влияние даты размещения (день недели, месяц, год);</h4>

# %%
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 7              5   7915000.0       71.60           2019-04-18      2
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16        51.00      8         False  ...
# ...

# %%
data['day_exposition'].corr(data['last_price'])
# Out:
# -0.013189241572589218

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Коэффициент корреляции рассчитывается для всех зависимостей из задания, исключая параметры - день недели и месяц — это не эффективно, т.к. это нелинейные параметры
#
# чтобы они стали линейными, январь месяц 2015 года должен стать третьим и т.д., т.е. мы должны сделать перекодировку ...

# %%
pivot_table_day = data.pivot_table(index = 'day_exposition', values = 'last_price', aggfunc=['median', 'count'])
pivot_table_day.columns = ['median', 'count']
pivot_table_day.plot(y='median', figsize=(6, 4)) 
plt.xlabel('День недели', size=10)
plt.ylabel('Стоимость квартиры', size=10)
print(pivot_table_day)
# Out:
#                    median  count
# day_exposition
# 0               4575000.0   3347
# 1               4650000.0   3897
# 2               4600000.0   3685
# 3               4510000.0   3960
# 4               4500000.0   3724
# 5               4500000.0   1822
# 6               4500000.0   1578

# %%
data['month_exposition'].corr(data['last_price'])
# Out:
# 0.01338603757751401

# %%
pivot_table_month = data.pivot_table(index = 'month_exposition', values = 'last_price', aggfunc=['median', 'count'])
pivot_table_month.columns = ['median', 'count']
pivot_table_month.plot(y='median', figsize=(6, 4)) 
plt.xlabel('Месяц', size=10)
plt.ylabel('Стоимость квартиры', size=10)
print(pivot_table_month)
# Out:
#                      median  count
# month_exposition
# 1                 4500000.0   1374
# 2                 4585000.0   2468
# 3                 4550000.0   2402
# 4                 4700000.0   2213
# 5                 4450000.0   1160
# 6                 4350000.0   1659
# 7                 4500000.0   1554
# 8                 4500000.0   1627
# 9                 4650000.0   1845
# 10                4540000.0   1987
# 11                4600000.0   2201
# 12                4600000.0   1523

# %%
data['year_exposition'].corr(data['last_price'])
# Out:
# -0.026502506959153092

# %%
pivot_table_year = data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc=['median', 'count'])
pivot_table_year.columns = ['median', 'count']
pivot_table_year.plot(y='median', figsize=(6, 4)) 
plt.xlabel('Год', size=10)
plt.ylabel('Стоимость квартиры', size=10)
print(pivot_table_year)
# Out:
#                     median  count
# year_exposition
# 2014             6200000.0     99
# 2015             5000000.0    992
# 2016             4445000.0   2588
# 2017             4450000.0   7619
# 2018             4500000.0   8027
# 2019             4990000.0   2688

# %% [markdown]
# По коэффициенту корреляции видно, что нет никакой заивисмости цены ни от дня недели, ни от месяца, ни от года в который выставили квартиру на продажу.В летние месяцы цена ниже. В 2015-2018 годах был спад.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить переменную
#
#         pivot_table_year = data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc=['median', 'count'])
#         pivot_table_year.columns = ['median', 'count']
#         pivot_table_year.plot(y='median', figsize=(6, 4))
#         plt.xlabel('Год', size=10)
#         plt.ylabel('Стоимость квартиры', size=10)
#         print(pivot_table_month)
#
# сейчас на экран мы выводим таблицу по месяцам

# %%
# check
pivot_table_year
# Out:
#                     median  count
# year_exposition
# 2014             6200000.0     99
# 2015             5000000.0    992
# 2016             4445000.0   2588
# 2017             4450000.0   7619
# 2018             4500000.0   8027
# 2019             4990000.0   2688

# %%
data.pivot_table(index = 'year_exposition', values = 'total_area', aggfunc=['median', 'count'])
# Out:
#                     median      count
#                 total_area total_area
# year_exposition
# 2014                  68.0         99
# 2015                  57.0        992
# 2016                  52.0       2588
# 2017                  51.0       7619
# 2018                  50.0       8027
# 2019                  51.0       2688

# %%
data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc=['median', 'count'])
# Out:
#                     median      count
#                 last_price last_price
# year_exposition
# 2014             6200000.0         99
# 2015             5000000.0        992
# 2016             4445000.0       2588
# 2017             4450000.0       7619
# 2018             4500000.0       8027
# 2019             4990000.0       2688

# %%
(data.pivot_table(index = 'year_exposition', values = 'price_metr', aggfunc = 'median')
 .plot(kind='bar', grid=True, figsize = (6, 4))
)
# Out:
# <AxesSubplot:xlabel='year_exposition'>

# %% [markdown]
# Стоимость квадраьного метра с каждым годом растет, площадь продоваемых объектов с 2014 резко упала, на что повлиях кризис 2014 года.

# %% [markdown]
# В динамике цен по годам наблюдается резкое снижение стоимости после 2015 года, что в целом объяснимо: в этот период начала восстанавливаться экономическая ситуация после кризиса 2014 года. Также этот график объясняет отрицательную динамику времени продажи в зависимости от года, очевидно, снижение цен повлияло на то, что квартиры стали продаваться быстрее.
# Самое большое влияние на стоимость недвижимости оказывают следующие параметры:
# Комбинация низкой платёжеспособности населения с искусственным всплеском покупательской активности всегда приводит к исчерпанию спроса будущих периодов. Ажиотаж 2014 г., напомним, закончился жесткой стагнацией 2015 г. Конечно, точное повторение событий четырехлетней давности совсем не обязательно, однако очевидно, что все основные факторы, обеспечившие всплеск спроса в 2018 г.
# Летние мемяцы спад в недвижимости, что очень вдияет на рынок, восстоновление идет с августа.
# в 2017 Одним из ключевых событий в экономике страны стало снижение ключевой ставки ЦБ. Что повдияло на восстоновление рынка недвижимости, льготные ипотеки.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Две колонки данных у тебя уже созданы: со стоимостью и с кол-ом объявлений, осталось создать подобную колонку с изменением  средней или медианной площади
#
# Для решения задачи
#
#          Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров)
#
# Берем твой код
#
#         data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc=['median', 'count'])
#
#
# для второй таблицы стоит в параметре values='last_price' заменить цену на общую площадь
#
#
# затем берем три колонки вместе и находим причину падения средних цен с 2014 по 2019 год

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Стоит добавить вывод
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 100 объявлений и 8000, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на сервис или рынок ИТ-торговли недвижимостью пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# <h4>Cредняя цена одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений</h4>

# %%
pivot_table_locality = data.pivot_table(index = 'locality_name', values = 'price_metr', aggfunc=['count'])
pivot_table_locality.columns = ['count']
print(pivot_table_locality.sort_values('count', ascending=False).head(10))
# Out:
#                  count
# locality_name
# Санкт-Петербург  14405
# Мурино             544
# Кудрово            437
# Шушары             426
# Всеволожск         383
# Пушкин             343
# Колпино            335
# Парголово          311
# Гатчина            302
# Выборг             227

# %%
local_top = data['locality_name'].value_counts().head(10)
pivot_table_local_top = data.query('locality_name in (@local_top.index)').pivot_table(values='price_metr', index='locality_name')
pivot_table_local_top.sort_values('price_metr', ascending=False)
# Out:
#                     price_metr
# locality_name
# Санкт-Петербург  110935.613259
# Пушкин           102124.775510
# Кудрово           95163.308924
# Парголово         90128.742765
# Мурино            85130.376838
# Шушары            78032.460094
# Колпино           75415.397015
# Всеволожск        68642.885117
# Гатчина           68623.632450
# Выборг            57648.083700

# %%
pivot_table_local_top.sort_values('price_metr').plot(kind='barh', figsize=(9,6), color='green')
# Out:
# <AxesSubplot:ylabel='locality_name'>

# %%
city_local_no_top = data['locality_name'].value_counts().tail(10)
city_price_sq_meter = data.query('locality_name in (@city_local_no_top.index)').pivot_table(values='price_metr', index='locality_name')
city_price_sq_meter.sort_values('price_metr', ascending=True)
# Out:
#                  price_metr
# locality_name
# Вахнова Кара          11688
# Лужайка               15000
# Большой Сабск         16453
# Тихковицы             21126
# Пустынка              27331
# Гладкое               30769
# Семиозерье            35714
# Трубников Бор         37523
# Русско                53125
# Александровская       63559

# %%
city_price_sq_meter.sort_values('price_metr').plot(kind='barh', figsize=(9,6), color='red')
# Out:
# <AxesSubplot:ylabel='locality_name'>

# %% [markdown]
# Cамая выскоая цена за квадратный метр в Санкт-Петербурге, самая низкая - в Лужайке.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  ТОП-10 найден
#
# осталось показать среднюю  стоимость кв. м. по населенным пунктам из полученного списка, затем строим график (бары), чтобы наглядно показать разницу в средней цене кв. метра ...
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 4.	Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         Тариф Ультра минуты
#         Среднее: 545.4511041009464
#         Дисперсия: 94104.36117385983
#         Стандартное отклонение: 306.76434143143143

# %% [markdown]
# <h4>Как стоимость объектов зависит от расстояния до центра города</h4>

# %%
locality_centr = data.query('locality_name == "Санкт-Петербург"')

display(locality_centr.head(20))
print(len(locality_centr))
locality_centr.shape[0]
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0           2019-03-07      3
# 2             10   5196000.0        56.0           2015-08-20      2
# 7              5   7915000.0        71.6           2019-04-18      2
# 9             18   5400000.0        61.0           2017-02-26      3
# 10             5   5050000.0        39.6           2017-11-16      1
# 15            16   4650000.0        39.0           2017-11-18      1
# 16            11   6700000.0        82.0           2017-11-23      3
# 17             6   4180000.0        36.0           2016-09-09      1
# 18             8   3250000.0        31.0           2017-01-27      1
# 19            16  14200000.0       121.0           2019-01-09      3
# 21            13   3200000.0        31.6           2018-03-14      1
# 23            11   2950000.0        32.0           2016-10-29      1
# 24             8   6500000.0        97.2           2015-10-31      2
# ...

# %%
locality_centr = data.query('locality_name == "Санкт-Петербург"')
locality_centr = locality_centr.pivot_table(index='distance_to_the_center', values='price_metr', aggfunc='mean').reset_index()
locality_centr
# Out:
#     distance_to_the_center     price_metr
# 0                      0.0  194329.866667
# 1                      1.0  146332.342657
# 2                      2.0  147707.325991
# 3                      3.0  120137.967857
# 4                      4.0  126172.021352
# 5                      5.0  132853.774457
# 6                      6.0  138958.519685
# 7                      7.0  142089.596045
# 8                      8.0  121774.871893
# 9                      9.0  111972.715827
# 10                    10.0  111856.335777
# 11                    11.0  107494.196270
# 12                    12.0  107275.684041
# 13                    13.0  107506.867098
# 14                    14.0  103528.003252
# 15                    15.0  103492.891639
# 16                    16.0  100030.730456
# 17                    17.0   96681.765197
# 18                    18.0   96661.243028
# 19                    19.0   97745.586667
# 20                    20.0   87214.526316
# ...

# %%
# locality_centr.pivot_table(index='distance_to_the_center', values='price_metr', aggfunc='mean')
# print(data_pivot_spb_center.sort_values('distance_to_the_center'))
# data_pivot_spb_center.sort_values('distance_to_the_center').plot(y='price_metr')

# %%
# locality_centr.pivot_table(index='distance_to_the_center', values='price_metr', aggfunc='mean')
# print(data_pivot_spb_center.sort_values('distance_to_the_center'))
# data_pivot_spb_center.sort_values('distance_to_the_center').plot(y='price_metr')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />закомментировал код, он не работал
#
# ![image.png](attachment:image.png)

# %%
data_locality_centr = data.query('locality_name == "Санкт-Петербург"').pivot_table(index='distance_to_the_center', values=['last_price'], aggfunc='mean').reset_index().plot(
                                                                                        kind='scatter',
                                                                                        x='distance_to_the_center', 
                                                                                        y='last_price',
                                                                                        grid=True,
                                                                                        figsize=(10,5),
                                                                                        title = 'Изменение стоимости за каждый километр')
plt.show()

# %% [markdown]
# Стоимость падает от отдаленности центар, есть незначительные выбросы на 30, 40км. но это может значить что элитная квартира. К примеру крестовкий остров.

# %%
data_locality_centr = data.query('locality_name == "Санкт-Петербург"').pivot_table(index='distance_to_the_center', values=['total_area'], aggfunc='mean').reset_index().plot(
                                                                                        kind='scatter',
                                                                                        x='distance_to_the_center', 
                                                                                        y='total_area',
                                                                                        grid=True,
                                                                                        figsize=(10,5),
                                                                                        title = 'Изменение стоимости площади квартиры')
plt.show()

# %%
data_locality_centr = data.query('locality_name == "Санкт-Петербург"').pivot_table(index='distance_to_the_center', values=['rooms'], aggfunc='mean').reset_index().plot(
                                                                                        kind='scatter',
                                                                                        x='distance_to_the_center', 
                                                                                        y='rooms',
                                                                                        grid=True,
                                                                                        figsize=(10,5),
                                                                                        title = 'Изменение стоимости взависимости от комнат')
plt.show()

# %%
data_locality_centr = data.query('locality_name == "Санкт-Петербург"').pivot_table(index='distance_to_the_center', values=['floor'], aggfunc='mean').reset_index().plot(
                                                                                        kind='scatter',
                                                                                        x='distance_to_the_center', 
                                                                                        y='floor',
                                                                                        grid=True,
                                                                                        figsize=(10,5),
                                                                                        title = 'Изменение стоимости взависимости от этажа')
plt.show()

# %% [markdown]
# До 10км все квартиры до 6 этажа, это говорит о историческом центре города до 5-6 этажей, чем ближе тем дороже.

# %%
data_spb_centr = data.query('locality_name == "Санкт-Петербург" and distance_to_the_center == 27')
display(data_spb_centr.head())
print('Квартир на 27км:', len(data_spb_centr))
print(data_spb_centr['locality_name'])
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 748             13  14350000.0        74.0           2017-11-28      2
# 5961             6   2250000.0        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 748             3.13             5         30.0      3         False  ...
# 5961            2.65             2         16.5      2         False  ...
#
#       parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 748          1496.0                0.0            NaN              128
# 5961            NaN                0.0            NaN              178
#
#      price_metr  day_exposition  month_exposition  year_exposition  \
# 748      193918               1                11             2017
# 5961      70312               1                 2             2018
#
#       floor_category  distance_to_the_center
# 748           Другой                    27.0
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается, кол-во наблюдений важный параметр для оценки качества данных
#
# у нас всего 2 записи на 27-м км., одна из которых с аномальной ценой, по этой причине мы отвергаем данное наблюдение

# %%
data_spb_centr.shape[0]
# Out:
# 2

# %%
data_spb_centr.plot(x='price_metr', y='total_area', kind='scatter', alpha=0.6)
# Out:
# <AxesSubplot:xlabel='price_metr', ylabel='total_area'>

# %%
data_spb_centr.plot(x='price_metr', y='rooms', kind='scatter', alpha=0.6)
# Out:
# <AxesSubplot:xlabel='price_metr', ylabel='rooms'>

# %%
data_spb_centr.plot(x='price_metr', y='ceiling_height', kind='scatter', alpha=0.6)
# Out:
# <AxesSubplot:xlabel='price_metr', ylabel='ceiling_height'>

# %% [markdown]
# Пик на 27км, его сложно объяснить, возможно это недвижимость в "особом" районе.

# %%
data_spb_centr_2 = data.query('locality_name == "Санкт-Петербург" and distance_to_the_center > 27')
display(data_spb_centr_2 .head())
print('Квартир дальше 27км:', len(data_spb_centr_2))
print(data_spb_centr_2['locality_name'])
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 814               0   7600000.0       111.0           2017-07-26      3
# 1111              0   4072000.0        38.0           2015-10-14      1
# 9572              0   3413000.0        43.0           2015-11-10      1
# 10798            10   4850000.0        62.0           2017-05-16      3
# 11652            16   4700000.0        51.0           2016-06-07      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 814              3.00            16         63.0     12         False  ...
# 1111             2.65             5         16.0      4         False  ...
# 9572             2.65             5         18.0      1         False  ...
# 10798            2.65             5         35.7      1         False  ...
# 11652            2.60             5         30.0      1         False  ...
#
#        parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# ...

# %%
data_spb_centr_2.plot(x='price_metr', y='total_area', kind='scatter', alpha=0.6)
# Out:
# <AxesSubplot:xlabel='price_metr', ylabel='total_area'>

# %%
data_spb_centr_3 = data.query('locality_name == "Санкт-Петербург" and distance_to_the_center <= 7')
display(data_spb_centr_3 .head())
print('Квартир дальше до 7км:', len(data_spb_centr_3))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 24             8   6500000.0        97.2           2015-10-31      2
# 61            18   7990000.0        74.0           2017-08-24      2
# 63             2  20000000.0       118.0           2018-09-11      3
# 94             3   3500000.0        29.5           2019-04-26      1
# 99            32   9600000.0        90.0           2017-09-26      4
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 24            2.65             3         46.5      1         False  ...
# 61            2.65             4         43.0      4         False  ...
# 63            3.00             9         68.0      7         False  ...
# 94            2.50             5         15.6      2         False  ...
# 99            2.65             5         67.0      2         False  ...
#
#     parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# ...

# %%
data_spb_centr_3.plot(x='price_metr', y='total_area', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='price_metr', ylabel='total_area'>

# %%
data_spb_centr_3.plot(x='price_metr', y='rooms', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='price_metr', ylabel='rooms'>

# %% [markdown]
# Вывод: в центре СПБ чем меньше комнат тем дороже стоимость метра квадратного, в отличие от всей выборки
# Хотя корреляция маленькая

# %%
data_spb_centr_3.plot(x='price_metr', y='floor_category', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='price_metr', ylabel='floor_category'>

# %%
spb = data.query('locality_name == "Санкт-Петербург" and distance_to_the_center <= 30')
display(spb .head())
print('Квартир до 30км:', len(spb)) 
spb_group_km = spb.groupby('distance_to_the_center')['price_metr'].median()
print(spb_group_km)
plt.plot(spb_group_km)
plt.xlim=10
plt.title('Ср cтоимость кв.метра в Санкт-Петербурге c 7 по 27км')
plt.ylabel('Медианная стоимость за кв. м, рублей')
plt.xlabel('Удаленность от центра, км')
plt.grid()
plt.show()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0           2019-03-07      3
# 2             10   5196000.0        56.0           2015-08-20      2
# 7              5   7915000.0        71.6           2019-04-18      2
# 9             18   5400000.0        61.0           2017-02-26      3
# 10             5   5050000.0        39.6           2017-11-16      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16         51.0      8         False  ...
# 2             2.65             5         34.3      4         False  ...
# 7             2.65            24         41.2     22         False  ...
# 9             2.50             9         43.6      7         False  ...
# 10            2.67            12         20.3      3         False  ...
#
#     parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# ...

# %%
data_spb_centr_pivot_group = spb.pivot_table(index=['distance_to_the_center', 'floor_category'], values="floor", aggfunc="count")
data_spb_centr_pivot_group.head(40)
# Out:
#                                        floor
# distance_to_the_center floor_category
# 0.0                    Другой              9
#                        Первый              3
#                        Последний           3
# 1.0                    Другой             88
#                        Первый             18
#                        Последний          37
# 2.0                    Другой            130
#                        Первый             37
#                        Последний          60
# 3.0                    Другой            167
#                        Первый             49
#                        Последний          64
# 4.0                    Другой            398
#                        Первый             74
#                        Последний          90
# 5.0                    Другой            552
#                        Первый             72
#                        Последний         112
# 6.0                    Другой            380
# ...

# %%
spb.groupby('floor_category')['last_price'].agg(['median']).sort_values(by='floor_category')
# Out:
#                    median
# floor_category
# Другой          5500000.0
# Первый          4800000.0
# Последний       5300000.0

# %% [markdown]
# Категория этажа не сильно влияет, но в центре первый этажей меньше всего.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Расчет принимается, подправим акценты вывода
#
# ![image.png](attachment:image.png)
#
# слева график для 3-го км., справа для 5-го км. (цифры для графиков не твои, но это не принципиально)
#
# Две стопки монет: в одной 8 золотых и 2 серебряные, во второй 6 золотых и 4 серебряные. В какой стопке средняя цена одной монеты будет дороже?
#
# Размер доли категорий квартир с более дешевой стоимостью намного больше на 3-м километре, чем на пятом, что является одной из причин падения и пика...
#
# возможно к этому фактору добавляются и другие

# %%
spb.groupby('distance_to_the_center')['last_price'].agg(['median']).sort_values(by='distance_to_the_center')
# Out:
#                             median
# distance_to_the_center
# 0.0                     10990000.0
# 1.0                      9900000.0
# 2.0                      9000000.0
# 3.0                      7950000.0
# 4.0                      8400000.0
# 5.0                      8500000.0
# 6.0                      8000000.0
# 7.0                      6999000.0
# 8.0                      6900000.0
# 9.0                      5202500.0
# 10.0                     4990000.0
# 11.0                     4990000.0
# 12.0                     4950000.0
# 13.0                     5200000.0
# 14.0                     4893500.0
# 15.0                     4850000.0
# 16.0                     4794500.0
# 17.0                     4589000.0
# 18.0                     4300000.0
# 19.0                     4500000.0
# 20.0                     4700000.0
# 21.0                     5210000.0
# 22.0                     4892500.0
# 23.0                     4590000.0
# 24.0                     3610000.0
# ...

# %%
pivot_table_price = spb.pivot_table(index = 'distance_to_the_center', values = 'last_price', aggfunc=['median', 'count'])
pivot_table_price.columns = ['median', 'count']
pivot_table_price.plot(y='median', figsize=(6, 4)) 
plt.xlabel('Расстояние до центра в км.', size=10)
plt.ylabel('средняя стоимость всех квартир', size=10)
print(pivot_table_price)
# Out:
#                             median  count
# distance_to_the_center
# 0.0                     10990000.0     15
# 1.0                      9900000.0    143
# 2.0                      9000000.0    227
# 3.0                      7950000.0    280
# 4.0                      8400000.0    562
# 5.0                      8500000.0    736
# 6.0                      8000000.0    508
# 7.0                      6999000.0    354
# 8.0                      6900000.0    523
# 9.0                      5202500.0    556
# 10.0                     4990000.0    682
# 11.0                     4990000.0   1126
# 12.0                     4950000.0   1554
# 13.0                     5200000.0   1392
# 14.0                     4893500.0   1230
# 15.0                     4850000.0   1495
# 16.0                     4794500.0   1228
# 17.0                     4589000.0    839
# 18.0                     4300000.0    251
# 19.0                     4500000.0    150
# 20.0                     4700000.0     19
# ...

# %% [markdown]
# На графике видно что  стоимость всех квартир подает до 10км, значит самый цент будет считатся в районе 9-10км

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         ты создаешь корректную выборку
#
#         locality_centr
#
# А остальные выборки содержат не только питерские квартиры, стоит поправить код во всем подразделе и корретно найти причины аномалий

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Для выполнения 5-го пункта стоит сгруппировать и найти среднюю стоимость __только питерских квартир__ на каждом километре, на этих данных построить линейный график, где по оси х будут округленные км., а по оси у - средняя стоимость всех квартир на этом км.
#
# Шаг 4.
#
# 5.	Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %%
data_spb_centr_pivot = data_spb_centr.pivot_table(index='rooms', values=['price_metr', 'total_area', 'ceiling_height'], aggfunc=['mean', 'count'])

display(data_spb_centr_pivot)

data_spb_centr[['total_area', 'price_metr', 'rooms', 'ceiling_height']].describe()
# Out:
#                 mean                                count             \
#       ceiling_height price_metr total_area ceiling_height price_metr
# rooms
# 1               2.65      70312       32.0              1          1
# 2               3.13     193918       74.0              1          1
#
#
#       total_area
# rooms
# 1              1
# 2              1
#        total_area     price_metr     rooms  ceiling_height
# count    2.000000       2.000000  2.000000        2.000000
# mean    53.000000  132115.000000  1.500000        2.890000
# std     29.698485   87402.640795  0.707107        0.339411
# min     32.000000   70312.000000  1.000000        2.650000
# 25%     42.500000  101213.500000  1.250000        2.770000
# 50%     53.000000  132115.000000  1.500000        2.890000
# 75%     63.500000  163016.500000  1.750000        3.010000
# max     74.000000  193918.000000  2.000000        3.130000

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Для решения задачи
#
#     Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре
#
# стоит выполнить группировку данных на питерских квартирах ⬇⬇⬇

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# locality_centr.pivot_table(index='rooms', values=['price_metr', 'total_area', 'ceiling_height'], aggfunc=['mean', 'count'])

# display(data_spb_centr_pivot)

# data_spb_centr[['total_area', 'price_metr', 'rooms', 'ceiling_height']].describe()

# %%
locality_centr = data.query('locality_name == "Санкт-Петербург"')

display(locality_centr.head(20))
print(len(locality_centr))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0           2019-03-07      3
# 2             10   5196000.0        56.0           2015-08-20      2
# 7              5   7915000.0        71.6           2019-04-18      2
# 9             18   5400000.0        61.0           2017-02-26      3
# 10             5   5050000.0        39.6           2017-11-16      1
# 15            16   4650000.0        39.0           2017-11-18      1
# 16            11   6700000.0        82.0           2017-11-23      3
# 17             6   4180000.0        36.0           2016-09-09      1
# 18             8   3250000.0        31.0           2017-01-27      1
# 19            16  14200000.0       121.0           2019-01-09      3
# 21            13   3200000.0        31.6           2018-03-14      1
# 23            11   2950000.0        32.0           2016-10-29      1
# 24             8   6500000.0        97.2           2015-10-31      2
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Для решения задачи
#
#         Стоит изучить записи, которые привели к выбросу на 27-м км., у нас аномалии на питерских квартирах ..
#
# стоит выполнить фильтрацию данных: оставить только питерские квартиры и только с 27-го километра
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Анализ объявлений о продаже квартир в Санкт-Петербурге и ближайших населенных пунктах, выявил, что наибольшее влияние на стоимость квартиры оказывает общая площадь квартиры и, несколько меньше, жилая площадь квартир. Ожидаемая корреляция между количеством комнат и стоимостью также была подтверждена. Не выявлено взаимосвязи между типом этажей здания и стоимостью квартир в указанной выборке.
# Взаимосвязи стоимости квартир с днем, месяцем, годом публикации объявления не выявлено, однако определены ряд тенденций, связанных со временем публикаций: стоимость объявлений оказалась выше в будние дни, в некоторых месяцах, а также снижение стоимости в периоде с 2014 по 2018 год.
# в различные года средняя стоимость недвижимости отличается, что обусловлено различными факторами в экономике
# Наибольшая стоимость кв.м в г. Санкт-Петербурге.
# Наименьшая Наименьшая в деревне Пчежва.
# Близость к центру один из значимых критериев влияющих на стоимость квартиры.
#
#
# Основная масса недвижимости выставляется на продажу вначале года. В конце весны начале лета наблюдается спад. Сначала лета и до декабря идёт постепенный рост выставления недвижимости на продажу, который заканчивается в декабре очередным спадом. В основном недвижимость продаётся в срок до 72 дней. Быстрой продажей можно считать срок до 45 дней. Долгой продажей - от 137 дней.
#
# По мере удаления квартир от центра города - цена за квадратный метр снижается.
#
# Большинство квартир имеют площадь менее 100 квадратных метров. Самые распространённые варианты с жилой площадью от 10 до 50 квадратных метров и площадью кухни - до 12 квадратных метров. Основная часть квартир это студии, однокомнатные, двухкомнатные.
#
# На первом и последнем этажах количество выставленных на продажу квартир значительно меньше, чем на других этажах. Квартиры, расположенные на первом этаже в среднем значительно дешевле.
#
# Влияет на стоимость квартир площадь помещения, чем большн квадратов тем стоимость больше за квартиру, стоимость квадрата зависит от бллизости к центру, района и поселка.
# менее сильное влияение оказывает количество комнат, но скорее всего это следствие того, что квартиры с большим количеством комнат имеют больше площадь
# Анализ параметров недвижимости позволил обнаружить границы, в которых начинаются аномалий, что позволит построить автоматизированную систему, которая будет отслеживать данные аномалии и мошенническую деятельность.
# Природа аномалий в данных может иметь разный характер:
# аномалии могут быть связаны с ошибками пользователей при занесении объявлений (Высота потолков, неверно указана площадь, расстояние)

# %% [markdown]
# <h1>Я уже устал от этого проекта 😔</h1>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Дальше будет легче, 😉

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец
#
# Критические ❌ комментарии
#
#
# + проверить корректность заполнения пропусков синтетическими данными
# + сменить тип данных
# + настроить фильтрацию редких значений в п. 2.4
# + добавить и подправить гистограммы в п.4.1
# + пересчитать скорость продаж
# + добавить вывод в п. 4.3
# + вывести на экран ТОП-10 и добавить график
# + поправить округление, поправить фильтрацию и исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'city_centers_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На примере ниже я покажу как фильтровать записи с пропусками
#
#
# Мягкие условия для удаления через логическую операцию или: оставляем все пропуски или все значения, которые ближе чем 60 000 метров
#
#         df_isna = df_check.query('airports_nearest.isna() | airports_nearest < 60000')
#
# В изначальном датасете было всего записей — 23699 entries, из них заполненные
#
#             15  airports_nearest      18157 non-null  float64
#
# Осталось — 23525 entries, из них заполненные
#
#             15  airports_nearest      17983 non-null  float64
#
# т.е. все пропуски в столбце airports_nearest остались на месте
#
# Знак | обозначает логическую операцию «или», иногда мы ее записываем при помощи оператора «or»

# %%
# check
try:
    df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')
    
df_check.info()
df_isna = df_check.query('airports_nearest.isna() | airports_nearest < 60000')
df_isna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример второго варианта фильтрации колонок с пропусками, в обновленной версии библиотеки пандас первый вариант работать, возможно, не будет

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 
df_check.info()
df_isna = df_check[(df_check ['airports_nearest'] < 60000) | (df_check ['airports_nearest'].isna()) ]

df_isna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример фильтрации колонок с пропусками по промежуткам

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 

# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 

df_check = df_check[
    (
        (df_check['airports_nearest'] < 70000) | (df_check['airports_nearest'].isna())
    ) & 
    (
        (df_check['airports_nearest'] > 40000) | (df_check['airports_nearest'] < 30000) | (df_check['airports_nearest'].isna())
    ) 
   ]

# %%
df_check['airports_nearest'].hist(bins = 100)
# Out:
# <AxesSubplot:>

# %%
df_check.drop(df_check.query('15000 < airports_nearest < 22000').index,inplace=True)

# %%
df_check['airports_nearest'].hist(bins = 100);

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15770 entries, 1 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          15770 non-null  int64
#  1   last_price            15770 non-null  float64
#  2   total_area            15770 non-null  float64
#  3   first_day_exposition  15770 non-null  object
#  4   rooms                 15770 non-null  int64
#  5   ceiling_height        9435 non-null   float64
#  6   floors_total          15710 non-null  float64
#  7   living_area           14442 non-null  float64
#  8   floor                 15770 non-null  int64
#  9   is_apartment          1828 non-null   object
#  10  studio                15770 non-null  bool
#  11  open_plan             15770 non-null  bool
#  12  kitchen_area          14175 non-null  float64
#  13  balcony               8063 non-null   float64
#  14  locality_name         15735 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все пропуски сохранены

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
